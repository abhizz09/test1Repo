# %%
import cv2
import pandas as pd
import numpy as np
import imutils
from scipy.spatial import distance as dist
from imutils import perspective
from imutils import contours
import matplotlib.pyplot as plt
import math

# %%
#cv2.imwrite("pendriveIMG2.jpg",saveimg[5])

# %%
img = cv2.imread("PICT0227.jpg",0)

# %%
#%matplotlib notebook

# %%
plt.imshow(img)

# %%
_ , imgThresh = cv2.threshold(img,30,100,cv2.THRESH_BINARY)
gauss = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,301,10)

# %%
plt.imshow(gauss)

# %%
#PICT0227.jpg [x,y]
tlup = [1617,1196]
trup = [2522,1202]
ml = [325,2172]
mr = [3797,2233]
bl = [382,2422]
br = [3739,2478]
allPoints = [tlup,trup,ml,mr,bl,br]

# %%
for i in allPoints:
    img = cv2.circle(img, tuple(i), 5, 0, 5)

# %%
#%matplotlib notebook

# %%
plt.imshow(img,"gray")

# %%
#PICT0235.jpg

tl = [193,1350]
tr = [3620,1430]
bl = [193,1638]
br = [3620,1690]
allPoints = [tl,tr,bl,br]

# %%
1203
# Out:
# 1203

# %%
tl[0]
# Out:
# 193

# %%
tr[0]
# Out:
# 3620

# %%
W = img.shape[1]
H = img.shape[0]

# %%
teta = 90 - (60/2)                          #................eqn1

# %%
beta = teta + ((H/2-bl[1]) * (60/H))        #................eqn2

# %%
sigma = (bl[0]-(W/2))*(120/H)               #................eqn3

# %% [markdown]
# # Depth

# %%
h = 93  #in cm
Y = h * math.tan(beta)                      #................eqn4
X = Y * math.tan(sigma)                     #................eqn5
Z = math.sqrt((h**2)+(Y**2)+(X**2))         #................eqn6

# %%
Z
# Out:
# 444.10525131453784

# %% [markdown]
# # Height

# %%
X = h *((ml[1]-bl[1])/bl[1])                #................eqn7

# %%
X
# Out:
# -9.599504541701073

# %%
15*30 - 3
# Out:
# 447

# %% [markdown]
# # length

# %%
X = h *((ml[0]-mr[0])/mr[0])                #................eqn7

# %%
X
# Out:
# -85.0397682380827

# %% [markdown]
# # long length

# %%
X = h *((tlup[1]-ml[1])/ml[1])                #................eqn7

# %%
X
# Out:
# -41.790055248618785

# %%
X * 10.2089
# Out:
# -426.6304950276243

# %%
X = h *((ml[0]-mr[0])/mr[0])                #................eqn7

# %%
h *((ml[1]-1306)/ml[1]) * 10.2089
# Out:
# 378.54714005524863

# %%
7*30 +15
# Out:
# 225

# %%
tlup[1] +110
# Out:
# 1306
