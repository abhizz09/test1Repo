# %%
import cv2
import pandas as pd
import numpy as np
import imutils
from scipy.spatial import distance as dist
from imutils import perspective
from imutils import contours
import matplotlib.pyplot as plt
import math

# %%
#cv2.imwrite("pendriveIMG2.jpg",saveimg[5])

# %%
img = cv2.imread("PICT0227.jpg",0)

# %%
#%matplotlib notebook

# %%
plt.imshow(img)

# %%
_ , imgThresh = cv2.threshold(img,30,100,cv2.THRESH_BINARY)
gauss = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,301,10)

# %%
plt.imshow(gauss)

# %%
#PICT0227.jpg [x,y]
tlup = [1617,1196]
trup = [2522,1202]
ml = [325,2172]
mr = [3797,2233]
bl = [382,2422]
br = [3739,2478]
allPoints = [tlup,trup,ml,mr,bl,br]

# %%
for i in allPoints:
    img = cv2.circle(img, tuple(i), 5, 0, 5)

# %%
#%matplotlib notebook

# %%
plt.imshow(img)

# %%
#PICT0235.jpg

'''tl = [193,1350]
tr = [3620,1430]
bl = [193,1638]
br = [3620,1690]
allPoints = [tl,tr,bl,br]'''
# Out:
# 'tl = [193,1350]\ntr = [3620,1430]\nbl = [193,1638]\nbr = [3620,1690]\nallPoints = [tl,tr,bl,br]'

# %%
1203
# Out:
# 1203

# %%
pts1 = np.float32([tlup,trup,ml,mr])
#pts1 = np.float32([tlup,trup,bl,br])
pts2 = np.float32([[325,0],[3797,0],[325,5172],[3797,5233]])
M = cv2.getPerspectiveTransform(pts1,pts2)
op = cv2.warpPerspective(img,M,(5000,5000))

# %%
plt.imshow(op)

# %%
M
# Out:
# array([[-1.61575774e+00, -2.53420947e+00,  5.50501332e+03],
#        [ 5.61959253e-02, -8.47621873e+00,  1.00466888e+04],
#        [ 8.86256797e-06, -1.20462817e-03,  1.00000000e+00]])

# %%
cap = cv2.VideoCapture(1)

while(True):
    ret, frame = cap.read()


    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-17-b7c5e899aac4> in <module>
#       5
#       6
# ----> 7     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#       8     cv2.imshow('frame',frame)
#       9     if cv2.waitKey(1) & 0xFF == ord('q'):
#
# error: OpenCV(3.4.5) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:181: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
cv2.findChessboardCorners()

# %%
point = [0,1]
rect = [0, 0, 10, 10]

# Create an instance of Subdiv2D
subdiv = cv2.Subdiv2D()
#subdiv.insert(point)

# %%
print(subdiv)
# Out:
# <Subdiv2D 000001AE2DA121F0>
