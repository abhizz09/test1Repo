# %%
data = "hello hello pyth hi yes no you are here"
def dispdatat(data):
    dictData = {}
    listData = data.split()
    print(listData)

# %%
#dispdatat(data)
data.split().count("hello")
# Out:
# 2

# %%
data = "hello hello pyth hi yes no you are here"
def dispdatat(data, *nikilk,**gvv):
    dictData = {}
    listData = data.split()
    #print(listData)
    for i in listData:
        #print("i = ",i)
        if i not in dictData:
            print("i = ",i)
            dictData[i] = listData.count(i)
            #print(dictData)
    print("updated dict", dictData)
    print(nikilk)

# %%
dispdatat(data)
# Out:
# i =  hello
# i =  pyth
# i =  hi
# i =  yes
# i =  no
# i =  you
# i =  are
# i =  here
# updated dict {'hello': 2, 'pyth': 1, 'hi': 1, 'yes': 1, 'no': 1, 'you': 1, 'are': 1, 'here': 1}
# ()

# %%
def
# Out:
#   File "<ipython-input-49-455680ca2399>", line 1
#     def
#         ^
# SyntaxError: invalid syntax

# %%
x = ["11"]

# %%
type(x)
# Out:
# list

# %%
type(x[0])
len(x[0])
# Out:
# 2

# %%
#n = input("enter the value u want to delete:\n")
listdata =[11,22,55,66]
def removedata(*niki):
    #print(len(niki))
    #print(niki)
    if len(niki)==0 or len(niki)>1:
        print("plz pass 1 niki")
    else:
        if niki[0] in listdata:
            pos = listdata.index()
            del listdata[pos]
            print("update list",listdata)
        else:
            print("niki is not present")
removedata(n)
# Out:
# enter the value u want to delete:
# 11
# niki is not present

# %%
listdata =[11,22,55,66]

# %%
listdata.index(1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-83ba14a02a7c> in <module>
# ----> 1 listdata.index(1)
#
# ValueError: 1 is not in list

# %%
n = input("enter the listdata:\n")
listdata = [11,22,33,44,55]

def deletdata(listdata,n):
    if n in listdata:
        del listdata(listdata.index[n])
        print("updated list",listdata)
deletdata(listdata,n)
# Out:
#   File "<ipython-input-2-a672e38e730e>", line 6
#     del listdata(listdata.index[n])
#        ^
# SyntaxError: can't delete function call

# %%
listdata = [11,12,13,14,"aa",("dtr"),["k",1]]

# %%
def deldat(listdata,data):
    index = listdata.index(data)
    del listdata[index]
    print("updated :",listdata)

# %%
inputx = int(input("enter what u want to del:"))
deldat(listdata,inputx)
# Out:
# enter what u want to del:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-8f47ff86d6d2> in <module>
# ----> 1 inputx = int(input("enter what u want to del:"))
#       2 deldat(listdata,inputx)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
float("aa")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-cfaeaa1d5f39> in <module>
# ----> 1 float("aa")
#
# ValueError: could not convert string to float: 'aa'

# %%
listdata = [1,2,3,4]

# %%
listdata.pop()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-48-42bb05dbe140> in <module>
# ----> 1 listdata.pop()
#
# IndexError: pop from empty list

# %%
pop.
# Out:
# [1, 2, 3]

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("C:/Users/shrin/Downloads/label_3.jpg",0)

# %%
plt.imshow(img)
