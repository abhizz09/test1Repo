# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import time
# %matplotlib inline
from imutils.video import count_frames
from scipy.spatial import distance as dist

# %%
#%matplotlib notebook

# %% [markdown]
#  # Video i/p

# %%
#0 - 2019-12-16 18-40-25-232.mov
count_frames("C:/Users/shrin/Documents/Abhilash/tata steel/Recordings/Export_2019-12-17_201401/0 - 2019-12-17 19-32-00-165.mov")
# Out:
# 19089

# %%
cap = cv2.VideoCapture("C:/Users/shrin/Documents/Abhilash/tata steel/Recordings/Export_2019-12-17_201401/0 - 2019-12-17 19-57-27-456.mov")
totalFrames = cap.get(cv2.CAP_PROP_FRAME_COUNT)
totalFrames
# Out:
# 19089.0

# %%
cap.set(cv2.CAP_PROP_POS_FRAMES,130)
# Out:
# True

# %%
# %matplotlib notebook

# %%
#ret, frame = cap.read()
imgIP = "ipImg/day2_9000_1.jpg"
frame = cv2.imread(imgIP)
frame = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
test = frame.copy()
#print(frame.shape)
#plt.figure(figsize=(10,12))
#plt.imshow(frame)

# %%
plt.imshow(frame)
# Out:
# <img src="data:image/png;base64,..." width="431.818172458775">

# %%
#cv2.imwrite("day2_18350_4.jpg",frame)

# %%
frame.shape
# Out:
# (1080, 1920, 3)

# %%
'''cv2.imshow("frame",frame)
cv2.waitKey(0)
cv2.destroyAllWindows()'''
# Out:
# 'cv2.imshow("frame",frame)\ncv2.waitKey(0)\ncv2.destroyAllWindows()'

# %%
alar = [1218+1,758-6,1478,759]
blbr = [1190,678,1416,684]
clcr = [1147+3,576,1332,582]
dldr = [1132+2,539,1300,544]
eler = [1118+1,503,1271-1,506]
refPoints = [alar,blbr,clcr,dldr,eler]

# %%
alar[-2:]
# Out:
# [1478, 759]

# %%
refImage = frame.copy()
for num,i in enumerate (refPoints):
    cv2.line(refImage,(i[0],i[1]),(i[2],i[3]),(255),5)
    #cv2.putText(refImage,"num",(850,i[1]),2,255,5,cv2.FONT_HERSHEY_SIMPLEX)
plt.figure(figsize=(10,12))
plt.imshow(refImage)

# %%
#%matplotlib notebook

# %%
plt.imshow(refImage)

# %%
[1128,540,1328,542]
[1117,504,1290,504]
# Out:
# [1117, 504, 1290, 504]

# %% [markdown]
# ### slab 3

# %%
# day2_1150_3.jpg
red_3_1 = [1207,752,1501,758]
red_3_2 = [1185+3,678,1450-2,682]
red_3_3 = [1146+3,578,1360-2,581]
red_3_4 = [1129+5,539,1326-1,543]
red_3_5 = [1121,502,1292,504]
slab3 = [red_3_1,red_3_2,red_3_3,red_3_4,red_3_5]

# %% [markdown]
# ### slab 2

# %%
# day2_5020_2.jpg
red_2_1 = [1203,727,1500,730]
red_2_2 = [1182+3,675,1450-2,677]
red_2_3 = [1144+3,575,1358-2,579]
red_2_4 = [1127+5,540,1326-3,542]
red_2_5 = [1114+2,504,1293-3,506]
slab2 = [red_2_1,red_2_2,red_2_3,red_2_4,red_2_5]

# %% [markdown]
# ### slab 1

# %%
# day2_9000_1.jpg
red1 = [1209+1,753,1515,758]
red2 = [1186,679,1454-2,685]
red3 = [1143+2,579,1360-1,580]
red4 = [1128,540,1328-5,542]
red5 = [1117,504,1290,504]
slab1 = [red1,red2,red3,red4,red5]

# %% [markdown]
# # pixels Per Metric

# %%
slabNumber = slab1

# %%
drawLine = frame.copy()
for i in range(5):
    dB = dist.euclidean(refPoints[i][:2],refPoints[i][-2:])
    pixelsPerMetric = dB / 1690
    print(1/pixelsPerMetric,"<<<<<-----------------")
    
    dB1 = dist.euclidean(slabNumber[i][:2],slabNumber[i][-2:])
    cv2.line(drawLine,(slabNumber[i][0],slabNumber[i][1]),(slabNumber[i][2],slabNumber[i][3]),0,6)
    refImage = cv2.circle(drawLine, (slabNumber[i][0],slabNumber[i][1]), 1, 0, 6)
    refImage = cv2.circle(drawLine, (slabNumber[i][2],slabNumber[i][3]), 1, 0, 6)
    
    dimB = dB1 / pixelsPerMetric
    print(dimB,"MM\t \t approx ERROR =", dimB - 1850,"\n")
# Out:
# 6.522714668282325 <<<<<-----------------
# 1989.6952802396536 MM	 	 approx ERROR = 139.69528023965358
#
# 7.4752421752300275 <<<<<-----------------
# 1988.9201977408964 MM	 	 approx ERROR = 138.92019774089636
#
# 9.280672420628306 <<<<<-----------------
# 1986.0855817101537 MM	 	 approx ERROR = 136.08558171015375
#
# 10.176107834578122 <<<<<-----------------
# 1984.4453953348611 MM	 	 approx ERROR = 134.44539533486113
#
# 11.189844772882688 <<<<<-----------------
# 1935.843145708705 MM	 	 approx ERROR = 85.84314570870492

# %%
for i in range(5):
    print(slab2[i][0]-slab2[i][2])
# Out:
# -297
# -263
# -209
# -191
# -174

# %%
#%matplotlib notebook

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
plt.figure(figsize=(10,12))
drawLine = cv2.putText(drawLine.copy(),"Width -> 1989.695280 mm".format(),(300,300), font, 1.82, (255,255,255), 7, cv2.LINE_AA)
plt.imshow(drawLine)

# %%
drawLine = cv2.cvtColor(drawLine,cv2.COLOR_RGB2BGR)
cv2.imwrite("C:/Users/shrin/Documents/Abhilash/report/day2_width.jpg",drawLine)
# Out:
# False

# %%
plt.imshow(refImage)

# %%
# slab 2

1924.7424678913421 MM	 	 approx ERROR = 74.74246789134213
2003.8669085693668 MM	 	 approx ERROR = 153.86690856936684
1986.410808741647 MM	 	 approx ERROR = 136.4108087416471
# Out:
#   File "<ipython-input-28-65bee8494eaa>", line 3
#     1924.7424678913421 MM	 	 approx ERROR = 74.74246789134213
#                         ^
# SyntaxError: invalid syntax

# %%
# slab 1

1989.6952802396536 MM	 	 approx ERROR = 139.69528023965358
2011.3402850176592 MM	 	 approx ERROR = 161.3402850176592
1986.0855817101537 MM	 	 approx ERROR = 136.08558171015375

# %%
# slab 3

1918.0774207796906 MM	 	 approx ERROR = 68.07742077969056
1981.16483127175 MM	 	 approx ERROR = 131.16483127175002
1986.259042753888 MM	 	 approx ERROR = 136.25904275388802

# %%
153+136+139+161+136+68+131+136+74

# %%
1134/9
